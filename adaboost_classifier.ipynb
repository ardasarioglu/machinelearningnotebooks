# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pls

# %%
df = pd.read_csv("16-diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df[df["Pregnancies"] == 0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4              0      137             40             35      168  43.1
# 16             0      118             84             47      230  45.8
# 45             0      180             66             39        0  42.0
# 57             0      100             88             60      110  46.8
# 58             0      146             82              0        0  40.5
# ..           ...      ...            ...            ...      ...   ...
# 713            0      134             58             20      291  26.4
# 727            0      141             84             26        0  32.4
# 736            0      126             86             27      120  27.4
# 753            0      181             88             44      510  43.3
# 757            0      123             72              0        0  36.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 4                       2.288   33        1
# ...

# %%
df[df["BMI"] == 0].shape
# Out:
# (11, 9)

# %%
df[df["BMI"] == 0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 9              8      125             96              0        0  0.0
# 49             7      105              0              0        0  0.0
# 60             2       84              0              0        0  0.0
# 81             2       74              0              0        0  0.0
# 145            0      102             75             23        0  0.0
# 371            0      118             64             23       89  0.0
# 426            0       94              0              0        0  0.0
# 494            3       80              0              0        0  0.0
# 522            6      114              0              0        0  0.0
# 684            5      136             82              0        0  0.0
# 706           10      115              0              0        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 9                       0.232   54        1
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
columns_to_fill = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI']

# %%
sns.histplot(df["DiabetesPedigreeFunction"])
# Out:
# <Axes: xlabel='DiabetesPedigreeFunction', ylabel='Count'>

# %%
sns.boxplot(y=df["DiabetesPedigreeFunction"], x=df["Outcome"])
# Out:
# <Axes: xlabel='Outcome', ylabel='DiabetesPedigreeFunction'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.stripplot(df, x="Outcome", y="DiabetesPedigreeFunction")
# Out:
# <Axes: xlabel='Outcome', ylabel='DiabetesPedigreeFunction'>

# %%
X = df.drop("Outcome", axis=1)
y = df["Outcome"]
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

# %%
medians = dict()
for col in columns_to_fill:
    median_value = X_train[X_train[col] != 0][col].median()
    X_train[col] = X_train[col].replace(0, median_value)
    medians[col] = median_value

for col in columns_to_fill:
    X_test[col] = X_test[col].replace(0, medians[col])

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 304            3      150             76             29    129.5  21.0
# 297            0      126             84             29    215.0  30.7
# 522            6      114             72             29    129.5  32.3
# 618            9      112             82             24    129.5  28.2
# 501            3       84             72             32    129.5  37.2
# ..           ...      ...            ...            ...      ...   ...
# 156            2       99             52             15     94.0  24.6
# 384            1      125             70             24    110.0  24.3
# 645            2      157             74             35    440.0  39.4
# 757            0      123             72             29    129.5  36.3
# 456            1      135             54             29    129.5  26.7
#
#      DiabetesPedigreeFunction  Age
# 304                     0.207   37
# 297                     0.520   24
# ...

# %%
X_train.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# mean      3.907166  121.560261      72.612378      29.040717  142.477199
# std       3.385438   29.974412      12.165642       8.312217   80.879330
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000  100.000000      64.000000      25.000000  125.000000
# 50%       3.000000  117.000000      72.000000      29.000000  129.500000
# 75%       6.000000  139.750000      80.000000      32.000000  130.000000
# max      17.000000  199.000000     122.000000      63.000000  680.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  614.000000                614.000000  614.000000
# mean    32.448208                  0.469948   33.285016
# std      6.862948                  0.328516   11.678337
# min     18.200000                  0.084000   21.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
ada = AdaBoostClassifier()
ada.fit(X_train, y_train)
y_pred = ada.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82       108
#            1       0.58      0.63      0.60        46
#
#     accuracy                           0.75       154
#    macro avg       0.71      0.72      0.71       154
# weighted avg       0.76      0.75      0.76       154
#
# [[87 21]
#  [17 29]]
# 0.7532467532467533

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    "n_estimators": [50,70,100,120,150,200],
    "learning_rate": [0.001, 0.1, 1, 10]
}

# %%
grid = GridSearchCV(estimator=AdaBoostClassifier(), param_grid=params)

# %%
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
print(grid.best_params_)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# {'learning_rate': 1, 'n_estimators': 150}
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82       108
#            1       0.59      0.65      0.62        46
#
#     accuracy                           0.76       154
#    macro avg       0.72      0.73      0.72       154
# weighted avg       0.77      0.76      0.76       154
#
# [[87 21]
#  [16 30]]
# 0.7597402597402597

# %%
grid = GridSearchCV(estimator=AdaBoostClassifier(), param_grid=params, cv=3, verbose=1, n_jobs=-1)
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
print(grid.best_params_)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# {'learning_rate': 1, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82       108
#            1       0.57      0.63      0.60        46
#
#     accuracy                           0.75       154
#    macro avg       0.70      0.71      0.71       154
# weighted avg       0.76      0.75      0.75       154
#
# [[86 22]
#  [17 29]]
# 0.7467532467532467

# %%
grid = GridSearchCV(estimator=AdaBoostClassifier(), param_grid=params, cv=5, verbose=1, n_jobs=-1)
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
print(grid.best_params_)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# {'learning_rate': 1, 'n_estimators': 150}
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82       108
#            1       0.59      0.65      0.62        46
#
#     accuracy                           0.76       154
#    macro avg       0.72      0.73      0.72       154
# weighted avg       0.77      0.76      0.76       154
#
# [[87 21]
#  [16 30]]
# 0.7597402597402597

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
for col in columns_to_fill:
    print(f"{col}: {df[df[col] == 0][col].shape[0]}")
# Out:
# Glucose: 5
# BloodPressure: 35
# SkinThickness: 227
# Insulin: 374
# BMI: 11

# %%
X = X.drop(["Insulin", "SkinThickness"], axis=1)

# %%
cols = ["Glucose","BloodPressure","BMI"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

# %%
for col in cols:
    median = X_train[X_train[col]!=0][col].median()
    X_train[col] = X_train[col].replace(0, median)
    X_test[col] = X_test[col].replace(0, median)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure   BMI  DiabetesPedigreeFunction  Age
# 304            3      150             76  21.0                     0.207   37
# 297            0      126             84  30.7                     0.520   24
# 522            6      114             72  32.3                     0.189   26
# 618            9      112             82  28.2                     1.282   50
# 501            3       84             72  37.2                     0.267   28
# ..           ...      ...            ...   ...                       ...  ...
# 156            2       99             52  24.6                     0.637   21
# 384            1      125             70  24.3                     0.221   25
# 645            2      157             74  39.4                     0.134   30
# 757            0      123             72  36.3                     0.258   52
# 456            1      135             54  26.7                     0.687   62
#
# [614 rows x 6 columns]

# %%
X_test
# Out:
#      Pregnancies  Glucose  BloodPressure   BMI  DiabetesPedigreeFunction  Age
# 343            5      122             86  34.7                     0.290   33
# 728            2      175             88  22.9                     0.326   22
# 73             4      129             86  35.1                     0.231   23
# 254           12       92             62  27.6                     0.926   44
# 741            3      102             44  30.8                     0.400   26
# ..           ...      ...            ...   ...                       ...  ...
# 582           12      121             78  26.5                     0.259   62
# 652            5      123             74  34.1                     0.269   28
# 83             0      101             65  24.6                     0.237   22
# 556            1       97             70  38.1                     0.218   30
# 267            2      128             64  40.0                     1.101   24
#
# [154 rows x 6 columns]

# %%
grid = GridSearchCV(estimator=AdaBoostClassifier(), param_grid=params)
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)

# %%
print(grid.best_params_)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# {'learning_rate': 1, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82       108
#            1       0.57      0.63      0.60        46
#
#     accuracy                           0.75       154
#    macro avg       0.70      0.71      0.71       154
# weighted avg       0.76      0.75      0.75       154
#
# [[86 22]
#  [17 29]]
# 0.7467532467532467

# %%
from sklearn.svm import SVC

# %%
params = {
    "C": [1,2,3,4,5,10],
    "kernel": ["linear", "poly", "rbf", "sigmoid"],
}
grid = GridSearchCV(estimator=SVC(), param_grid=params)
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
print(grid.best_params_)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# {'C': 2, 'kernel': 'linear'}
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83       108
#            1       0.59      0.57      0.58        46
#
#     accuracy                           0.75       154
#    macro avg       0.70      0.70      0.70       154
# weighted avg       0.75      0.75      0.75       154
#
# [[90 18]
#  [20 26]]
# 0.7532467532467533

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
params = {
    "criterion": ["gini","entropy","log_loss"],
    "splitter": ["best", "random"],
    "max_depth": [5,10,20,None]
}
grid = GridSearchCV(estimator=DecisionTreeClassifier(), param_grid=params)
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
print(grid.best_params_)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'splitter': 'best'}
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       108
#            1       0.54      0.54      0.54        46
#
#     accuracy                           0.73       154
#    macro avg       0.67      0.67      0.67       154
# weighted avg       0.73      0.73      0.73       154
#
# [[87 21]
#  [21 25]]
# 0.7272727272727273

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
params = {
    "n_estimators": [5,10,20,50,100,200],
    "criterion": ["gini","entropy","log_loss"],
    "max_depth": [5,20,50,None]
}
grid = GridSearchCV(estimator=RandomForestClassifier(), param_grid=params)
grid.fit(X_train, y_train)
y_pred = grid.predict(X_test)
print(grid.best_params_)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# {'criterion': 'entropy', 'max_depth': 50, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82       108
#            1       0.57      0.63      0.60        46
#
#     accuracy                           0.75       154
#    macro avg       0.70      0.71      0.71       154
# weighted avg       0.76      0.75      0.75       154
#
# [[86 22]
#  [17 29]]
# 0.7467532467532467
